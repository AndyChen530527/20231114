# %%
#小明想要存錢買一輛機車,機車每輛30000元，他將每月存的錢輸入，當存款足夠買機車時，就顯示提示訊息告知。
import pyinputplus as pyip
deposit = 0
month = 0
while deposit < 30000:
    month += 1
    money_month = pyip.inputInt(f"請輸入第{month}月份存款:")    
    print(money_month)
    deposit += money_month

print(f"恭喜!已經存夠了,共存了{month}月份,總存款為:{deposit}")
# Out:
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:'q' is not an integer.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:Blank values are not allowed.
# 請輸入第1月份存款:1
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:Blank values are not allowed.
# 請輸入第2月份存款:2
# 請輸入第3月份存款:2
# 請輸入第4月份存款:2
# 請輸入第5月份存款:2
# 請輸入第6月份存款:2
# 請輸入第7月份存款:2
# 請輸入第8月份存款:2
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:Blank values are not allowed.
# 請輸入第9月份存款:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/20231114/lessen7_1.ipynb 儲存格 1 line 7
#       <a href='vscode-notebook-cell://codespaces%2Bfantastic-space-adventure-5gg4qjvw65w9377j5/workspaces/20231114/lessen7_1.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> while deposit < 30000:
#       <a href='vscode-notebook-cell://codespaces%2Bfantastic-space-adventure-5gg4qjvw65w9377j5/workspaces/20231114/lessen7_1.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     month += 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bfantastic-space-adventure-5gg4qjvw65w9377j5/workspaces/20231114/lessen7_1.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     money_month = pyip.inputInt(f"請輸入第{month}月份存款:")
#       <a href='vscode-notebook-cell://codespaces%2Bfantastic-space-adventure-5gg4qjvw65w9377j5/workspaces/20231114/lessen7_1.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     print(money_month)
#       <a href='vscode-notebook-cell://codespaces%2Bfantastic-space-adventure-5gg4qjvw65w9377j5/workspaces/20231114/lessen7_1.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     deposit += money_month
#
# File ~/.local/lib/python3.10/site-packages/pyinputplus/__init__.py:486, in inputInt(prompt, default, blank, timeout, limit, strip, allowRegexes, blockRegexes, applyFunc, postValidateApplyFunc, min, max, lessThan, greaterThan)
#     471 pysv._validateParamsFor_validateNum(min=min, max=max, lessThan=lessThan, greaterThan=greaterThan)
#     473 validationFunc = lambda value: pysv.validateNum(
#     474     value,
#     475     blank=blank,
#    (...)
#     483     _numType="int",
#     484 )
# --> 486 result = _genericInput(
#     487     prompt=prompt,
#     488     default=default,
#     489     timeout=timeout,
#     490     limit=limit,
#     491     applyFunc=applyFunc,
#     492     validationFunc=validationFunc,
#     493 )
#     495 try:
#     496     result = int(float(result))
#
# File ~/.local/lib/python3.10/site-packages/pyinputplus/__init__.py:156, in _genericInput(prompt, default, timeout, limit, applyFunc, validationFunc, postValidateApplyFunc, passwordMask)
#     154 print(prompt, end="")
#     155 if passwordMask is None:
# --> 156     userInput = input()
#     157 else:
#     158     userInput = stdiomask.getpass(prompt="", mask=passwordMask)
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py:1251, in Kernel.raw_input(self, prompt)
#    1249     msg = "raw_input was called, but this frontend does not support input requests."
#    1250     raise StdinNotImplementedError(msg)
# -> 1251 return self._input_request(
#    1252     str(prompt),
#    1253     self._parent_ident["shell"],
#    1254     self.get_parent("shell"),
#    1255     password=False,
#    1256 )
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py:1295, in Kernel._input_request(self, prompt, ident, parent, password)
#    1292 except KeyboardInterrupt:
#    1293     # re-raise KeyboardInterrupt, to truncate traceback
#    1294     msg = "Interrupted by user"
# -> 1295     raise KeyboardInterrupt(msg) from None
#    1296 except Exception:
#    1297     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#輸入小寫的英文字,列印出第一個字大寫的英文字
#如果輸入q,就會離開

stuff = pyip.inputStr("請輸入小寫英文字[按q會離開]:")
while(stuff != 'q'):
    print(stuff.capitalize())
    stuff = pyip.inputStr("請輸入小寫英文字[按q會離開]:")
    
print("結束程式")
# Out:
# 請輸入小寫英文字[按q會離開]:結束程式

# %%
#輸入小寫的英文字,列印出第一個字大寫的英文字
#如果輸入q,就會離開

while(True):
    stuff = pyip.inputStr("請輸入小寫英文字[按q會離開]:")
    if stuff == 'q':
        break
    print(stuff.capitalize())
    
    
    
print("結束程式")
# Out:
# 請輸入小寫英文字[按q會離開]:Abc
# 請輸入小寫英文字[按q會離開]:結束程式

# %%
#小美是一位教師，請你以while迴圈方式為小美設計一個輸入成績的程式，如果輸入負數表示成績輸入結束，在輸入成績結束後顯示班上總成績及平均成績。
sum = 0
num = 0
while(True):        
    score = pyip.inputInt(f"請輸入第{num+1}位學生成績:")
    print(score)
    if score<0:
        break
    num += 1
    sum += score

print(f"全班總成績:{sum},平均為{sum/num}")

# %%
#顯示:
#奇數輸出平方
#偶數不做任何動作
#'q'要離開

while(True):
    value = input("請輸入整數,輸入[q]離開:")
    if value == 'q':
        break
    
    valueInt = int(value)
    if valueInt % 2 == 1:
        print(f"{valueInt}的平方是{valueInt ** 2}")
    else:
        print("不做事")

print("應用程式結束")
# Out:
# 不做事
# 3的平方是9
# 37的平方是1369
# 應用程式結束

# %%
#顯示:
#奇數輸出平方
#偶數不做任何動作
#'q'要離開

while(True):
    value = input("請輸入整數,輸入[q]離開:")
    if value == 'q':
        break
    
    try:
        valueInt = int(value)
    except:
        print(f"{value}格式錯誤")
        continue
    
    if valueInt % 2 == 1:
        print(f"{valueInt}的平方是{valueInt ** 2}")
    else:
        print("不做事")

print("應用程式結束")
# Out:
# 23的平方是529
# 不做事
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 格式錯誤
# 應用程式結束
